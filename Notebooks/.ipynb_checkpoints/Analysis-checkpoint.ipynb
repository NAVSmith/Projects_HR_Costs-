# %% [markdown]
# # exploring

# %%
import pandas as pd
import numpy as np
import datetime
import re
from scipy import stats
import matplotlib.pyplot as plt

# %%
pd.set_option("display.max_rows", 300)

# %%
df = pd.read_csv("../Cleaned_Data/Tasks.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25012 entries, 0 to 25011
# Data columns (total 11 columns):
# Unnamed: 0          25012 non-null int64
# User                25012 non-null object
# Project             25012 non-null object
# Task_Category       25012 non-null object
# Task_Description    25012 non-null object
# Date                25012 non-null object
# Duration            25012 non-null object
# Time_Decimal        25012 non-null float64
# Cost_per_hour       25012 non-null float64
# Position            25012 non-null object
# Task_Cost           25012 non-null float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 2.1+ MB

# %%
# reording the data to make it more understandable
df.Cost_per_hour = df.Cost_per_hour.round(2)
df.Time_Decimal = df.Time_Decimal.round(2)
df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
 df = df[["Date", "Duration", "Project", "Task_Category", "Task_Cost", "Task_Description", "User", "Position", "Cost_per_hour","Time_Decimal"]]

# %%
df
# Out:
#              Date  Duration        Project Task_Category  Task_Cost  \
# 0      2017-09-01  01:17:00       Revenify   Development      26.41
# 1      2017-09-01  02:30:00            WWU   Development      62.50
# 2      2017-09-01  00:36:49            WWU   Development      15.34
# 3      2017-09-01  00:12:05            WWU   Development       5.03
# 4      2017-09-01  00:09:07            WWU   Development       3.80
# ...           ...       ...            ...           ...        ...
# 25007  2019-09-28  00:41:22     CareBetter   Development      24.13
# 25008  2019-09-28  00:20:55  CandidatePool   Development       8.46
# 25009  2019-09-28  01:02:00  CandidatePool   Development      29.02
# 25010  2019-09-28  00:20:59     CareBetter   Development      12.24
# 25011  2019-09-28  00:16:44     CareBetter   Development       9.76
#
#                                         Task_Description  User  \
# 0      Feedback on budgets index PR and Standup meeti...  UI13
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Duration', 'Project', 'Task_Category', 'Task_Cost',
#        'Task_Description', 'User', 'Position', 'Cost_per_hour',
#        'Time_Decimal'],
#       dtype='object')

# %%
# 23 projects! are massured
len(list(df.Project.unique()))
# Out:
# 23

# %%
# turing the Duration into timedelata
df.Duration = pd.to_timedelta(df.Duration)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25012 entries, 0 to 25011
# Data columns (total 10 columns):
# Date                25012 non-null object
# Duration            25012 non-null timedelta64[ns]
# Project             25012 non-null object
# Task_Category       25012 non-null object
# Task_Cost           25012 non-null float64
# Task_Description    25012 non-null object
# User                25012 non-null object
# Position            25012 non-null object
# Cost_per_hour       25012 non-null float64
# Time_Decimal        25012 non-null float64
# dtypes: float64(3), object(6), timedelta64[ns](1)
# memory usage: 1.9+ MB

# %% [markdown]
# # Avg cost:
# 1) by project
# 2) By catogory (Devlopment (Backend, Frontend, Full stack, Tech Lead)
# 3) by seniorty
# 4) calulate

# %% [markdown]
# ## Avg
# ### all
# median = 32.16 (from all projects)
# mean = 32.14 (from all hours)
# as we can see 32.1 USD is the avg of a programmer
# ### over 1000 hours
#
# ### under 1000 hours but more thne 100

# %% [markdown]
# ## for all the data

# %%
# call the mean
df.Task_Cost.sum()/df.Time_Decimal.sum()
# Out:
# 32.136385297567145

# %%
#cal the median per 
# to most expensive per hour project
exp_pro = df[['Project', 'Task_Category', 'Task_Cost', 'Duration', 'Time_Decimal','User', 'Position', 'Task_Description']]

# %%
def add_avg_cost_per_hour(df):
    return df.assign(mean_cost_per_hour_per_pro= lambda x : round(x.Task_Cost / x.Time_Decimal, 2))

def group_n_add_cost_avg(df, col):
    return add_avg_cost_per_hour(df.groupby(col).sum().reset_index())

# %%
cost_per_hour_per_pro =  group_n_add_cost_avg(exp_pro, ['Project'])
#.assign(mean_cost_per_hour_per_pro= lambda x : round(x.Task_Cost / x.Time_Decimal, 2)))

# %%
cost_per_hour_per_pro
# Out:
#           Project  Task_Cost  Time_Decimal  mean_cost_per_hour_per_pro
# 0     AgeSolvency  163039.50       3878.65                       42.04
# 1   BetterBooking    1344.96         60.41                       22.26
# 2   CandidatePool   56206.17       1414.82                       39.73
# 3      CareBetter   33001.50        814.97                       40.49
# 4        Credious  367619.45      15104.62                       24.34
# 5        DBboards   20472.29        606.02                       33.78
# 6       FinFunnel    7008.62        180.97                       38.73
# 7         Finizon  238705.00       5735.63                       41.62
# 8         Fintech    7938.72        305.35                       26.00
# 9      FreshMarkt    2297.10         91.90                       25.00
# 10            GDP   74276.23       1939.68                       38.29
# 11     GlobalMove    8922.03        215.95                       41.32
# ...

# %%
cost_per_hour_per_pro.describe()
# Out:
#            Task_Cost  Time_Decimal  mean_cost_per_hour_per_pro
# count      23.000000     23.000000                   23.000000
# mean    66702.993913   2075.622174                   34.772174
# std     96734.200810   3456.556955                    9.923824
# min       392.000000     13.970000                   22.260000
# 25%      8430.375000    223.475000                   27.265000
# 50%     24730.010000    814.970000                   33.780000
# 75%     65241.200000   1824.150000                   40.110000
# max    367619.450000  15104.620000                   64.600000

# %%
plt.hist(x = cost_per_hour_per_pro.mean_cost_per_hour_per_pro, bins = 7)
plt.show()

# %% [markdown]
# # varibles name:
# exp_pro complete data frame
#
# lar10_exp_pro for only projects over 1000 hours
#
# sma10_exp_peo for only projects under 1000 hours but more then 100.

# %% [markdown]
# ## project over 1000 hours = big projects

# %%
# lets take projects out are over 1000 hours  
len(cost_per_hour_per_pro[cost_per_hour_per_pro.Time_Decimal > 1000])
# it is 10 project!
# meadian is 34.42
# Out:
# 10

# %%
largest_project_10 = list(cost_per_hour_per_pro[cost_per_hour_per_pro.Time_Decimal > 1000].Project.values)
largest_project_10
# Out:
# ['AgeSolvency',
#  'CandidatePool',
#  'Credious',
#  'Finizon',
#  'GDP',
#  'NestPride',
#  'PilotAxis',
#  'Revenify',
#  'TeachZip',
#  'WeVape']

# %%
lar10_exp_pro = exp_pro[exp_pro.Project.isin(largest_project_10)]

# %%
lar10_exp_pro.Task_Cost.sum()/lar10_exp_pro.Time_Decimal.sum()
# avg of cost per hour in the large project is 31.84
# Out:
# 31.83826919531754

# %%
group_n_add_cost_avg(lar10_exp_pro, ['Project'] )
# Out:
#          Project  Task_Cost  Time_Decimal  mean_cost_per_hour_per_pro
# 0    AgeSolvency  163039.50       3878.65                       42.04
# 1  CandidatePool   56206.17       1414.82                       39.73
# 2       Credious  367619.45      15104.62                       24.34
# 3        Finizon  238705.00       5735.63                       41.62
# 4            GDP   74276.23       1939.68                       38.29
# 5      NestPride   37047.82       1278.65                       28.97
# 6      PilotAxis  132264.15       3401.42                       38.88
# 7       Revenify   42552.71       1708.62                       24.90
# 8       TeachZip  236927.51       7755.82                       30.55
# 9         WeVape   33014.99       1178.09                       28.02

# %%
group_n_add_cost_avg(lar10_exp_pro, ['Project'] ).describe()
# Out:
#            Task_Cost  Time_Decimal  mean_cost_per_hour_per_pro
# count      10.000000     10.000000                   10.000000
# mean   138165.353000   4339.600000                   33.734000
# std    112737.243095   4361.426134                    7.040669
# min     33014.990000   1178.090000                   24.340000
# 25%     45966.075000   1488.270000                   28.257500
# 50%    103270.190000   2670.550000                   34.420000
# 75%    218455.507500   5271.385000                   39.517500
# max    367619.450000  15104.620000                   42.040000

# %%
plt.hist(x = cost_per_hour_per_pro[cost_per_hour_per_pro.Time_Decimal > 1000].mean_cost_per_hour_per_pro, bins = 5)
plt.show()

# %% [markdown]
# ## small projects

# %%
# lets take projects out are under 1000 hours  and over 100 hours
len(cost_per_hour_per_pro[(cost_per_hour_per_pro.Time_Decimal < 1000) & (cost_per_hour_per_pro.Time_Decimal > 100)])
# it is 10 projects
# Out:
# 10

# %%
smallest_project_10= (list(cost_per_hour_per_pro[(cost_per_hour_per_pro.Time_Decimal < 1000) & (cost_per_hour_per_pro.Time_Decimal > 100)]
      .Project.values))

# %%
sma10_exp_pro = exp_pro[exp_pro.Project.isin(smallest_project_10)]

# %%
sma10_exp_pro.Task_Cost.sum()/sma10_exp_pro.Time_Decimal.sum()
# Out:
# 35.54709207259703

# %%
group_n_add_cost_avg(sma10_exp_pro, ['Project'] )
# Out:
#       Project  Task_Cost  Time_Decimal  mean_cost_per_hour_per_pro
# 0  CareBetter   33001.50        814.97                       40.49
# 1    DBboards   20472.29        606.02                       33.78
# 2   FinFunnel    7008.62        180.97                       38.73
# 3     Fintech    7938.72        305.35                       26.00
# 4  GlobalMove    8922.03        215.95                       41.32
# 5  IntellHive   24730.01        893.57                       27.68
# 6   LearnSage    5303.70        106.03                       50.02
# 7    SharpDev   14922.45        231.00                       64.60
# 8   Sinbuffer   14237.49        378.31                       37.63
# 9         WWU   11944.46        444.86                       26.85

# %%
group_n_add_cost_avg(sma10_exp_pro, ['Project'] ).describe()
# Out:
#           Task_Cost  Time_Decimal  mean_cost_per_hour_per_pro
# count     10.000000     10.000000                   10.000000
# mean   14848.127000    417.703000                   38.710000
# std     8838.362992    271.496087                   11.820533
# min     5303.700000    106.030000                   26.000000
# 25%     8184.547500    219.712500                   29.205000
# 50%    13090.975000    341.830000                   38.180000
# 75%    19084.830000    565.730000                   41.112500
# max    33001.500000    893.570000                   64.600000

# %% [markdown]
# ## exploring Categories

# %%
##'Task_Category' 
# exp_pro

# %%
exp_pro.Task_Category.value_counts()
# Out:
# Development    17968
# DevOps          3549
# QA              2980
# Design           515
# Name: Task_Category, dtype: int64

# %% [markdown]
# ### we see that there is no large diffrence between costs for all the projects ans only the largests whe it comes to slicing by work category. allogh when it come to huge project it can be factor in
# Desgin work ~= 23.3/23.4 $ per hour
#
# DevOps = 28.5/29 $ per hour
#
# Development = 34/34.5 $ per hour
#
# QA = 19.75/19.76 per hour

# %% [markdown]
# ### more analysis_
# development constitutes the bulk of resources in terms of cost and in time spent in a given project.
# But there are difrennces beteen the time and cost alloction. that should be factored while writing a peojects propsal.
# also note that QA is need only in big projects... and design about half the nin big projcts
# but DEvops is need about 4.5 points in smaller projects then biger onces and about 2.4 points more costs then the genreal mean (we explore the Devops more below)

# %%
def anal_by_category(df):
    grouped_n_avg_df = group_n_add_cost_avg(df, ['Task_Category'])
    grouped_n_avg_df['Time_p%_4m_total'] = round(100 * grouped_n_avg_df.Time_Decimal / sum(grouped_n_avg_df.Time_Decimal),2)
    grouped_n_avg_df['Cost_p%_4m_total'] =  round(100 * grouped_n_avg_df.Task_Cost / sum(grouped_n_avg_df.Task_Cost),2)
    return grouped_n_avg_df

# %%
anal_by_category(exp_pro)
# Out:
#   Task_Category   Task_Cost  Time_Decimal  mean_cost_per_hour_per_pro  \
# 0        Design    42145.16       2074.00                       20.32
# 1        DevOps   120795.26       4221.45                       28.61
# 2   Development  1295424.34      37608.12                       34.45
# 3            QA    75804.10       3835.74                       19.76
#
#    Time_p%_4m_total  Cost_p%_4m_total
# 0              4.34              2.75
# 1              8.84              7.87
# 2             78.78             84.44
# 3              8.03              4.94

# %%
anal_by_category(lar10_exp_pro)
# Out:
#   Task_Category   Task_Cost  Time_Decimal  mean_cost_per_hour_per_pro  \
# 0        Design    39869.54       1960.21                       20.34
# 1        DevOps   105890.61       3680.89                       28.77
# 2   Development  1160186.04      33920.98                       34.20
# 3            QA    75707.34       3833.92                       19.75
#
#    Time_p%_4m_total  Cost_p%_4m_total
# 0              4.52              2.89
# 1              8.48              7.66
# 2             78.17             83.97
# 3              8.83              5.48

# %%
anal_by_category(sma10_exp_pro)
# Out:
#   Task_Category  Task_Cost  Time_Decimal  mean_cost_per_hour_per_pro  \
# 0        Design    2275.62        113.79                       20.00
# 1        DevOps   14512.65        526.59                       27.56
# 2   Development  131596.24       3534.83                       37.23
# 3            QA      96.76          1.82                       53.16
#
#    Time_p%_4m_total  Cost_p%_4m_total
# 0              2.72              1.53
# 1             12.61              9.77
# 2             84.63             88.63
# 3              0.04              0.07

# %% [markdown]
# ## deep diving into the devops component
# let do an analysis by projects to check for outliers in the data.
#  we can see that there is an outlier in the data for the DevOps the FinTech projects that it was 100% DevOps work
# #compare the devlopment-- the data is to small for a deep dive but one can see the diffrance in range
# See what we can get from that

# %%
def anal_by_category_by_project(df):
    test=group_n_add_cost_avg(df, ['Project','Task_Category'])
    # gernerate a new array that is same shape an leangh of the orginal of 
    #and costistes of the total time spent on each project
    test1 =test.copy().groupby('Project').Time_Decimal.sum()[test.Project].reset_index().drop(columns=["Project"])
    # append this total arry as a new column to the df 
    test['Total_time_project'] =  test1
    # creates an new columns that is the % of the paricular task catergory time form the total time spent on the project
    test['Task_Time_p%_4m_total'] = round(100 *   test.Time_Decimal / test.Total_time_project,2)
    # repeats on for the Task costs
    test2 =test.copy().groupby('Project').Task_Cost.sum()[test.Project].reset_index().drop(columns=["Project"])
    test['Total_cost_project'] =  test2
    test['Task_cost_p%_4m_total'] = round(100 *   test.Task_Cost / test.Total_cost_project,2)
    # drops the midway columns
    return test.drop(columns=['Total_time_project', 'Total_cost_project'])
    # There is a more efficient way or shorter to do this use np.arrays but considering the small scope of the data it is ok.

# %%
deep_dive_sma10 = anal_by_category_by_project(sma10_exp_pro)
deep_dive_sma10
# Out:
#        Project Task_Category  Task_Cost  Time_Decimal  \
# 0   CareBetter        Design    1843.98         92.20
# 1   CareBetter        DevOps     192.33          5.63
# 2   CareBetter   Development   30965.19        717.14
# 3     DBboards        Design     431.64         21.59
# 4     DBboards   Development   20040.65        584.43
# 5    FinFunnel        DevOps     718.89         26.57
# 6    FinFunnel   Development    6289.73        154.40
# 7      Fintech        DevOps    7938.72        305.35
# 8   GlobalMove   Development    8922.03        215.95
# 9   IntellHive        DevOps     808.89         24.18
# 10  IntellHive   Development   23921.12        869.39
# 11   LearnSage        DevOps     345.36         13.27
# 12   LearnSage   Development    4958.34         92.76
# 13    SharpDev   Development   14922.45        231.00
# 14   Sinbuffer        DevOps    3134.59        100.25
# 15   Sinbuffer   Development   11006.14        276.24
# ...

# %%
pivot_sma10_time = deep_dive_sma10.pivot(columns = "Task_Category", index = 'Project', values= 'Task_Time_p%_4m_total').reset_index()
pivot_sma10_time
# we can see that there is an outlier in the data for the DevOps the FinTech projects that it was 100% DevOps work
# compare the devlopment-- the data is to small for a deep dive but one can see the diffrance in range.
# Out:
# Task_Category     Project  Design  DevOps  Development    QA
# 0              CareBetter   11.31    0.69        88.00   NaN
# 1                DBboards    3.56     NaN        96.44   NaN
# 2               FinFunnel     NaN   14.68        85.32   NaN
# 3                 Fintech     NaN  100.00          NaN   NaN
# 4              GlobalMove     NaN     NaN       100.00   NaN
# 5              IntellHive     NaN    2.71        97.29   NaN
# 6               LearnSage     NaN   12.52        87.48   NaN
# 7                SharpDev     NaN     NaN       100.00   NaN
# 8               Sinbuffer     NaN   26.50        73.02  0.48
# 9                     WWU     NaN   11.54        88.46   NaN

# %%
plt.hist(x = pivot_sma10_time.DevOps, bins = 8)
plt.show()

# %%
# compare the devlopment-- the data is to small for a deep dive but one can see the diffrance in range.
plt.hist(x = pivot_sma10_time.Development, bins = 8)
plt.show()

# %%
pivot_sma10_time[['DevOps', 'Development']].describe()
# Out:
# Task_Category      DevOps  Development
# count            7.000000     9.000000
# mean            24.091429    90.667778
# std             34.527081     8.757491
# min              0.690000    73.020000
# 25%              7.125000    87.480000
# 50%             12.520000    88.460000
# 75%             20.590000    97.290000
# max            100.000000   100.000000

# %%
# Even without the outlier we can see that the 12 % stays the same 
pivot_sma10_time[['DevOps', 'Development']][pivot_sma10_time.Project != 'Fintech'].describe()
# Out:
# Task_Category     DevOps  Development
# count           6.000000     9.000000
# mean           11.440000    90.667778
# std             9.276346     8.757491
# min             0.690000    73.020000
# 25%             4.917500    87.480000
# 50%            12.030000    88.460000
# 75%            14.140000    97.290000
# max            26.500000   100.000000

# %%
pivot_sma10_cost = deep_dive_sma10.pivot(columns = "Task_Category", index = 'Project', values= 'Task_cost_p%_4m_total').reset_index()
pivot_sma10_cost
# Out:
# Task_Category     Project  Design  DevOps  Development    QA
# 0              CareBetter    5.59    0.58        93.83   NaN
# 1                DBboards    2.11     NaN        97.89   NaN
# 2               FinFunnel     NaN   10.26        89.74   NaN
# 3                 Fintech     NaN  100.00          NaN   NaN
# 4              GlobalMove     NaN     NaN       100.00   NaN
# 5              IntellHive     NaN    3.27        96.73   NaN
# 6               LearnSage     NaN    6.51        93.49   NaN
# 7                SharpDev     NaN     NaN       100.00   NaN
# 8               Sinbuffer     NaN   22.02        77.30  0.68
# 9                     WWU     NaN   11.50        88.50   NaN

# %%
pivot_sma10_cost[['DevOps', 'Development']].describe()
# Out:
# Task_Category      DevOps  Development
# count            7.000000     9.000000
# mean            22.020000    93.053333
# std             35.075263     7.194581
# min              0.580000    77.300000
# 25%              4.890000    89.740000
# 50%             10.260000    93.830000
# 75%             16.760000    97.890000
# max            100.000000   100.000000

# %%
pivot_sma10_cost[['DevOps', 'Development']][pivot_sma10_cost.Project != 'Fintech'].describe()
# Out:
# Task_Category     DevOps  Development
# count           6.000000     9.000000
# mean            9.023333    93.053333
# std             7.580028     7.194581
# min             0.580000    77.300000
# 25%             4.080000    89.740000
# 50%             8.385000    93.830000
# 75%            11.190000    97.890000
# max            22.020000   100.000000

# %% [markdown]
# ## deep diving into the devlopment component
# See what we can get from that

# %%
### mean of pure development costs is 34.45(from the table above) and median from prjects is 39.84
## 
def anal_devlopment(df):
    return group_n_add_cost_avg(df[df.Task_Category == 'Development'], ['Project'])

# %%
anal_devlopment(exp_pro).describe()
# Out:
#            Task_Cost  Time_Decimal  mean_cost_per_hour_per_pro
# count      21.000000     21.000000                   21.000000
# mean    61686.873333   1790.862857                   36.968571
# std     78259.529827   2543.672150                   10.797231
# min      1344.960000     60.410000                   22.260000
# 25%     10570.590000    231.000000                   27.510000
# 50%     29922.430000    869.390000                   39.840000
# 75%     62003.510000   1468.200000                   42.750000
# max    253660.050000  10071.950000                   64.600000

# %%
anal_devlopment(lar10_exp_pro).describe()
# Out:
#            Task_Cost  Time_Decimal  mean_cost_per_hour_per_pro
# count      10.000000     10.000000                   10.000000
# mean   116018.604000   3392.098000                   35.729000
# std     85153.140436   2975.934384                    8.450564
# min     29922.430000   1054.600000                   25.180000
# 25%     40738.197500   1314.562500                   28.520000
# 50%     90321.700000   2121.735000                   37.100000
# 75%    193773.110000   4317.895000                   42.665000
# max    253660.050000  10071.950000                   45.290000

# %%
anal_devlopment(sma10_exp_pro).describe()
# Out:
#           Task_Cost  Time_Decimal  mean_cost_per_hour_per_pro
# count      9.000000      9.000000                    9.000000
# mean   14621.804444    392.758889                   41.310000
# std     8716.482966    270.868276                   11.959878
# min     4958.340000     92.760000                   26.860000
# 25%     8922.030000    215.950000                   34.290000
# 50%    11006.140000    276.240000                   40.740000
# 75%    20040.650000    584.430000                   43.180000
# max    30965.190000    869.390000                   64.600000

# %% [markdown]
# ## position and seniority
# seniority is devided into two groups :
#
# Senior: employees with senior in thier title or Tech Leads/ Mangers
#
# Junior: employees with junior in ther title or no junior or senior where mentioned

# %%
exp_pro
# Out:
#              Project Task_Category  Task_Cost Duration  Time_Decimal  User  \
# 0           Revenify   Development      26.41 01:17:00          1.28  UI13
# 1                WWU   Development      62.50 02:30:00          2.50  UI36
# 2                WWU   Development      15.34 00:36:49          0.61  UI36
# 3                WWU   Development       5.03 00:12:05          0.20  UI38
# 4                WWU   Development       3.80 00:09:07          0.15  UI36
# ...              ...           ...        ...      ...           ...   ...
# 25007     CareBetter   Development      24.13 00:41:22          0.69  UI35
# 25008  CandidatePool   Development       8.46 00:20:55          0.35  UI20
# 25009  CandidatePool   Development      29.02 01:02:00          1.03  UI14
# 25010     CareBetter   Development      12.24 00:20:59          0.35  UI35
# 25011     CareBetter   Development       9.76 00:16:44          0.28  UI35
#
#                           Position
# ...

# %%
df.Position.value_counts()
# Out:
# Project Manager / Tech Lead    6590
# Senior Full-Stack Developer    3995
# Quality Assurance              2817
# Front End Developer            2591
# Back End Developer             2219
# Full-Stack Developer           1613
# Devops                         1361
# Senior Back End Developer      1097
# Senior Devops                   848
# Junior Back End Developer       733
# Designer                        515
# Junior Front End Developer      416
# Senior Front End Developer      217
# Name: Position, dtype: int64

# %%
def add_seniority(df):
    df['seniority'] = np.where(df.Position.str.contains('Senior|Lead', regex=True), 'Senior', 'Junior')
    df['work'] = (np.where(df.Position.str.contains('Back', regex=True), 'Back End',  
             np.where(df.Position.str.contains('Front', regex=True), 'Front End',
             np.where(df.Position.str.contains('Full', regex=True), 'Full-Stack',
             np.where(df.Position.str.contains('Devops', regex=True), 'Devops',
             np.where(df.Position.str.contains('Tech', regex=True), 'Lead',
             np.where(df.Position.str.contains('Designer', regex=True), 'Design',
                      'QA')))))))
    return df
def anal_position(df , work_or_seniority):
    grouped_n_avg_df = group_n_add_cost_avg(add_seniority(df), [work_or_seniority])
    grouped_n_avg_df['Time_p%_4m_total'] = round(100 * grouped_n_avg_df.Time_Decimal / sum(grouped_n_avg_df.Time_Decimal),2)
    grouped_n_avg_df['Cost_p%_4m_total'] =  round(100 * grouped_n_avg_df.Task_Cost / sum(grouped_n_avg_df.Task_Cost),2)
    return grouped_n_avg_df

# %%
anal_position(exp_pro, 'seniority')
# Out:
#   seniority  Task_Cost  Time_Decimal  mean_cost_per_hour_per_pro  \
# 0    Junior  617479.41      24844.15                       24.85
# 1    Senior  916689.45      22895.16                       40.04
#
#    Time_p%_4m_total  Cost_p%_4m_total
# 0             52.04             40.25
# 1             47.96             59.75

# %%
## large projects
anal_position(lar10_exp_pro, 'seniority')
# Out:
# /Users/nadavsmith/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/nadavsmith/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#   seniority  Task_Cost  Time_Decimal  mean_cost_per_hour_per_pro  \
# 0    Junior  571884.00       23231.5                       24.62
# 1    Senior  809769.53       20164.5                       40.16
#
# ...

# %%
anal_position(sma10_exp_pro, 'seniority')
# Out:
# /Users/nadavsmith/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/nadavsmith/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#   seniority  Task_Cost  Time_Decimal  mean_cost_per_hour_per_pro  \
# 0    Junior   41734.09       1449.76                       28.79
# 1    Senior  106747.18       2727.27                       39.14
#
# ...

# %%
anal_position(exp_pro, 'work')
# Out:
#          work  Task_Cost  Time_Decimal  mean_cost_per_hour_per_pro  \
# 0    Back End  266924.14       9625.94                       27.73
# 1      Design   42145.16       2074.00                       20.32
# 2      Devops   70749.93       2968.11                       23.84
# 3   Front End  223787.87       8460.88                       26.45
# 4  Full-Stack  382291.02      10702.19                       35.72
# 5        Lead  477714.44      10194.61                       46.86
# 6          QA   70556.30       3713.58                       19.00
#
#    Time_p%_4m_total  Cost_p%_4m_total
# 0             20.16             17.40
# 1              4.34              2.75
# 2              6.22              4.61
# 3             17.72             14.59
# 4             22.42             24.92
# 5             21.35             31.14
# 6              7.78              4.60

# %%
anal_position(lar10_exp_pro, 'work')
# Out:
# /Users/nadavsmith/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/nadavsmith/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#          work  Task_Cost  Time_Decimal  mean_cost_per_hour_per_pro  \
# 0    Back End  253294.06       9265.45                       27.34
# 1      Design   39869.54       1960.21                       20.34
# ...

# %%
anal_position(sma10_exp_pro, 'work')
# Out:
# /Users/nadavsmith/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/nadavsmith/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#          work  Task_Cost  Time_Decimal  mean_cost_per_hour_per_pro  \
# 0    Back End   13630.08        360.49                       37.81
# 1      Design    2275.62        113.79                       20.00
# ...

# %% [markdown]
# # tasks from project
# making a table that shows cost and time sats on tasks (group by the description columns in the df)

# %% [markdown]
# ### most expensive task is code review witch costs 39.15 dollars an hour

# %%
def tasks_with_word(word):
    return df[df.Task_Description.str.lower().str.contains(word, regex=True)]

# %%
def tasks_with_list(tup):
    pattern='|'.join(tup[1])
    return df[df.Task_Description.str.lower().str.contains(pattern, regex=True)]

# %%
def idea(df):
    lst_all_words = ' '.join(df.Task_Description).lower().split()
    lst_all_words_cleaned = [re.sub(r'[^a-zA-Z]','', i)for i in lst_all_words]
    lst_all_words_cleaned_no_stop_words = [word for word in lst_all_words_cleaned if word not in stop_word]
    return pd.Series(lst_all_words_cleaned_no_stop_words).value_counts()

# %%
stop_word = ["i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than", "too", "very", "s", "t", "can", "will", "just", "don", "should", "now", 'xxx', 'x', '-', 'new', 'fafsa', '+', '&', '[fafsa]',]
stop_word1 = ['working', 'work', 'user', 'experience', 'sf', 'continue', ':', 'one', '2.', 'agent', 'able', 'credit','end', 'prospect', 'status', 'based',  'endpoint', 'management', '','number', 'docker', 'text', 'back', 'component', 'version',  'prs', 'bds', 'need',  'portal','website', 'plaid', 'code', 'add', 
 '1.', 'xxx', 'users', '[fafsa]',  'go',  '[xxx', 'form', 'tab',  'profile',  'site', 'job', 'tu' ,'debt', 'last', 'crm',  'landing',  '/',  'button', 'financial',  'secxty', 'gds', 'tradeline', 'screen', 'app', 'pages', 'admin', 'make', 'xxx,', 'page', 'manager']
stop_word = stop_word + stop_word1

# %%
word_ser = pd.Series([re.sub(r'[^a-zA-Z0-9]','', i)for i in' '.join(df.Task_Description).lower().split()]).value_counts()
word_ser
# Out:
# xxx            7490
# on             5825
#                4868
# to             4857
# the            4677
#                ...
# viewports         1
# ttd               1
# 2continue         1
# saw               1
# backslashes       1
# Length: 6342, dtype: int64

# %%
# checking for the 200 most commen words minus stop words to creat a list of subjects
lst_all_words = ' '.join(df.Task_Description).lower().split()
lst_all_words_cleaned = [re.sub(r'[^a-zA-Z]','', i)for i in lst_all_words]
lst_all_words_cleaned_no_stop_words = [word for word in lst_all_words_cleaned if word not in stop_word]
list(pd.Series(lst_all_words_cleaned_no_stop_words).value_counts()[:200].index)
# Out:
# ['testing',
#  'review',
#  'meeting',
#  'staging',
#  'standup',
#  'automation',
#  'sprint',
#  'production',
#  'update',
#  'changes',
#  'issue',
#  'weekly',
#  'create',
#  'planning',
#  'deployment',
#  'test',
#  'fix',
#  'design',
#  'frontend',
#  'call',
#  'discussion',
#  'fixing',
#  'daily',
#  'backend',
#  'integration',
#  'server',
#  'release',
#  'funnel',
#  'data',
#  'flow',
#  'deploy',
#  'issues',
#  'adding',
#  'team',
#  'bug',
#  'tests',
#  'debts',
#  'setup',
#  'qa',
#  'client',
#  'feature',
#  'project',
#  'implement',
#  'creating',
#  'fixes',
#  'program',
#  'research',
#  'env',
#  'pr',
#  'devops',
#  'api',
#  'tested',
#  'report',
#  'error',
#  'refactor',
#  'implementation',
#  'information',
#  'tickets',
#  'talk',
#  'change',
#  'updating',
#  'sanity',
#  'view',
#  'functionality',
#  'login',
#  'prod',
#  'db',
#  'feedback',
#  'documentation',
#  'tradelines',
#  'details',
#  'search',
#  'deploying',
#  'tasks',
# ...

# %%
#subjects to explore 
testing = ( 'testing' ,['test ', 'testing', 'tested', 'qa ', 'regression', 'sanity'])
meetings =( 'meetings', ['meeting', 'weekly', 'daily', 'standup', 'call ', 'calling' , 'discussion', 'talk', 'sync ', 'demo ', 'discuss'])
planing = ( 'planing', ['sprint', 'plan'])
code_review = ('code_review' ,['review'])
deployment = ('deployment', ['staging', 'production', 'env ', 'environment', 'pr ', "prod ", 'deploy','release', 'releasing'])
seting_up = ( 'seting_up',['setup','setting', 'set ', ])
automation = ('automation', ['automation',])
fixing_bugs_n_rewriting = ( 'fixing_bugs',['fix ', 'fixed', 'fixing', 'fixes', 'refactor', 'bug ', 'solve', 'solving', 'issue', 'error', 'adjustments', 'debugging', 'debug'])
research = ('research', ['research'])
update = ('update',['update', 'updating', 'changes'])
create = ('create',['create ', 'creating', 'build ', 'building' ])
planning_n_designing =('planning_n_designing', ['planning', 'plan ', 'design'])
server = ('server', ['server'])
documentation =('documentation', ['documentation'])
helping =('helping', ['support', 'help ', 'helping', ])
onboarding = ( 'onboarding' ,['environment', 'onboard'])
environment = ('environment', ['environment', 'env '])

# %%
master_list_subjects = [testing, meetings, planing, code_review, deployment, seting_up, automation, fixing_bugs_n_rewriting,
                        research, update,create, planning_n_designing, server, documentation, helping, onboarding , environment]

# %%
master_list_subjects.sort()

# %%
tasks_with_list(testing)
# Out:
#              Date Duration        Project Task_Category  Task_Cost  \
# 23     2017-09-05 05:16:39       Revenify   Development     108.61
# 87     2017-09-13 00:46:36       Revenify   Development      15.98
# 99     2017-09-14 02:44:24       Revenify   Development      56.39
# 118    2017-09-15 02:35:58       Revenify   Development      53.50
# 232    2017-09-28 00:09:08            WWU   Development       3.81
# ...           ...      ...            ...           ...        ...
# 24891  2019-09-23 04:11:49  CandidatePool   Development     252.01
# 24923  2019-09-24 04:15:30  CandidatePool   Development     255.69
# 24948  2019-09-25 01:25:42         WeVape   Development      42.85
# 24971  2019-09-26 00:31:10         WeVape        DevOps      15.58
# 25000  2019-09-27 03:03:00  CandidatePool   Development     183.14
#
#                                         Task_Description  User  \
# 23     Doing some tests around  the logic of a user s...  UI13
# ...

# %%
def cal_cost_per_hour(words_list):
    return round( tasks_with_list(words_list).Task_Cost.sum() / tasks_with_list(words_list).Time_Decimal.sum() ,2)

# %%
# Out:
# 5227.41

# %%
# how many entries each of the subseted tasks has
count_entries = (pd.Series({tup[0]:len(tasks_with_list(tup)) for tup in master_list_subjects})
                 .reset_index().rename(columns={0: 'count_entries'})) 

avg_cost_subset_task = (pd.Series({ tup[0]:cal_cost_per_hour(tup) for tup in master_list_subjects })
                        .reset_index().rename(columns={0: 'avg_cost_subtask'}))

avg_time_entries =( pd.Series({tup[0]:round(tasks_with_list(tup).Time_Decimal.mean(),2) for tup in master_list_subjects})
                   .reset_index().rename(columns={0: 'avg_time_entries'}))

median_time_entries =(pd.Series({tup[0]:round(tasks_with_list(tup).Time_Decimal.median(),2) for tup in master_list_subjects})
                       .reset_index().rename(columns={0: 'median_time__entries'}))

# %%
## creating a data frame of all the subsettask information
stats_exp_pro=(pd.merge(count_entries, 
          pd.merge(avg_cost_subset_task, 
                   pd.merge(avg_time_entries,  
                            median_time_entries, how='inner', on='index'), how='inner', on='index'),how='inner', on='index')).rename(columns={'index':'subtask'})
## let play whith the data ()

# %%
# mean of cost per hour on the subseted task(made from the description)
avg_cost_subset_task.values
# Out:
# array([['automation', 19.89],
#        ['code_review', 39.15],
#        ['create', 34.09],
#        ['deployment', 30.87],
#        ['documentation', 29.97],
#        ['environment', 35.17],
#        ['fixing_bugs', 30.78],
#        ['helping', 28.34],
#        ['meetings', 32.01],
#        ['onboarding', 34.12],
#        ['planing', 33.29],
#        ['planning_n_designing', 32.51],
#        ['research', 36.34],
#        ['server', 35.23],
#        ['seting_up', 33.5],
#        ['testing', 27.73],
#        ['update', 27.5]], dtype=object)

# %%
# mean of cost per hour on the subseted task(made from the description)
avg_cost_subset_task.values
# Out:
#                    index  avg_cost_subtask
# 0             automation             19.89
# 1            code_review             39.15
# 2                 create             34.09
# 3             deployment             30.87
# 4          documentation             29.97
# 5            environment             35.17
# 6            fixing_bugs             30.78
# 7                helping             28.34
# 8               meetings             32.01
# 9             onboarding             34.12
# 10               planing             33.29
# 11  planning_n_designing             32.51
# 12              research             36.34
# 13                server             35.23
# 14             seting_up             33.50
# 15               testing             27.73
# 16                update             27.50

# %% [markdown]
# ## ploting time(each entry is a dot) for subset task to see rangen in the data.
# most are skeded to the left as expected as expected
# We see that some entries are long and do not make sense
# like for meetings some entries are over 2 hours.
# #  the goal is to see the % of each tasks total time for the whole sum of all the time worked on 1)the whole data farme.. 2) 10 largest projcects 3) 10 smalles projects
# ## we now that some entries reffer not just one task given but a few of them.. for example some one clocked in 8 hour were he dworked on 3 diffeent assiments and took part in 2 meetings. so we need to correct. note that we do not want to calculate for the skew and try to normlaze the data so we be closer to the mean. the sekw (as show below) is very high above 1 and show left skewness. thta make sense as entries should tend to be from 30 mintus to a few hours (that is the way how much people work on thier assigments). the leaning to the left shows a tendency that
# ## as a resulat  the way I elected to do so is to use the median as tool. As the median smaller then the mean we assume it is more correct(but still lager then the real mean.
# ## we'll take the medain an multiply it by the count of entries to resive an esstmation of how many hours we acculy devoted for each subset of tasks. then calulate the % form the whole clocked

# %%
tasks_with_list(testing).describe()
# Out:
#                      Duration    Task_Cost  Cost_per_hour  Time_Decimal
# count                    2596  2596.000000    2596.000000   2596.000000
# mean          0 days 02:00:49    55.845104      26.080447      2.013640
# std    0 days 02:04:01.170447    74.936281      12.679521      2.067027
# min           0 days 00:00:55     0.000000       0.000000      0.020000
# 25%           0 days 00:31:12    11.640000      18.000000      0.520000
# 50%    0 days 01:14:29.500000    30.695000      22.310000      1.240000
# 75%           0 days 02:56:17    71.675000      27.500000      2.940000
# max           0 days 17:10:00   806.190000      80.940000     17.170000

# %%
tasks_with_list(testing).skew()
# Out:
# Task_Cost        3.449506
# Cost_per_hour    1.867217
# Time_Decimal     1.866130
# dtype: float64

# %%
for tup in master_list_subjects:
    plt.hist(x = tasks_with_list(tup).Time_Decimal, bins = 50)
    plt.xlabel(tup[0].title(), fontsize='xx-large')
    plt.show()

# %%
plt.hist(x = tasks_with_list(testing).Time_Decimal, bins = 30)
plt.xlabel(testing[0].title(), fontsize='xx-large')
plt.show()

# %%
plt.hist(x = tasks_with_list(meetings).Time_Decimal, bins = 30)
plt.show()

# %% [markdown]
# ## data about all the projects
#
# so around %13.5 of the time is dedicted for fixing bugs
# arounf 9% for deployment
# meeting is arond %5.5.
# code review %4.7
# testing %6.7

# %%
stats_exp_pro['estimated_total_time'] = stats_exp_pro['count_entries'] * stats_exp_pro['median_time__entries']
stats_exp_pro['estimated_total_cost'] = stats_exp_pro['count_entries'] * stats_exp_pro['avg_cost_subtask']
stats_exp_pro['estimated_%_f4_total_time'] = round(100 *stats_exp_pro.estimated_total_time / exp_pro.Time_Decimal.sum(), 2)
stats_exp_pro['estimated_%_f4_total_cost'] = round(100 *stats_exp_pro.estimated_total_cost / exp_pro.Task_Cost.sum(), 2)
stats_exp_pro['estimated_%_f4_total_cost'].reset_index()
# Out:
#     index  estimated_%_f4_total_cost
# 0       0                       1.40
# 1       1                       3.87
# 2       2                       2.61
# 3       3                       7.36
# 4       4                       0.43
# 5       5                       0.78
# 6       6                       6.63
# 7       7                       0.67
# 8       8                       8.11
# 9       9                       0.62
# 10     10                       3.25
# 11     11                       3.30
# 12     12                       1.06
# 13     13                       1.09
# 14     14                       1.87
# 15     15                       4.69
# 16     16                       3.60

# %%
# Out:
#                            count_entries  avg_cost_subtask  avg_time_entries  \
# count_entries                   1.000000         -0.180809         -0.323184
# avg_cost_subtask               -0.180809          1.000000          0.493777
# avg_time_entries               -0.323184          0.493777          1.000000
# median_time__entries           -0.479305          0.196019          0.895504
# new                             0.844061         -0.151505          0.072727
# estimated_total_time            0.844159         -0.151493          0.072608
# estimated_%_f4_total_time       0.844061         -0.151505          0.072727
#
#                            median_time__entries       new  \
# count_entries                         -0.479305  0.844061
# avg_cost_subtask                       0.196019 -0.151505
# avg_time_entries                       0.895504  0.072727
# median_time__entries                   1.000000 -0.042994
# new                                   -0.042994  1.000000
# ...

# %% [markdown]
# ## data for the  10 small project

# %%
def tasks_with_list_sma10(tup):
    pattern='|'.join(tup[1])
    return sma10_exp_pro[sma10_exp_pro.Task_Description.str.lower().str.contains(pattern, regex=True)]

# %%
def cal_cost_per_hour_sma10(words_list):
    return round( tasks_with_list_sma10(words_list).Task_Cost.sum() / tasks_with_list_sma10(words_list).Time_Decimal.sum() ,2)

# %%
# how many entries each of the subseted tasks has
count_entries_sma10 = (pd.Series({tup[0]:len(tasks_with_list_sma10(tup)) for tup in master_list_subjects})
                 .reset_index().rename(columns={0: 'count_entries'})) 

avg_cost_subset_task_sma10 = (pd.Series({ tup[0]:cal_cost_per_hour_sma10(tup) for tup in master_list_subjects })
                        .reset_index().rename(columns={0: 'avg_cost_subtask'}))

avg_time_entries_sma10 =( pd.Series({tup[0]:round(tasks_with_list_sma10(tup).Time_Decimal.mean(),2) for tup in master_list_subjects})
                   .reset_index().rename(columns={0: 'avg_time_entries'}))

median_time_entries_sma10 =(pd.Series({tup[0]:round(tasks_with_list_sma10(tup).Time_Decimal.median(),2) for tup in master_list_subjects})
                       .reset_index().rename(columns={0: 'median_time__entries'}))

# %%
## creating a data frame of all the subsettask information
stats_exp_pro_sma10=(pd.merge(count_entries_sma10, 
          pd.merge(avg_cost_subset_task_sma10, 
                   pd.merge(avg_time_entries_sma10,  
                            median_time_entries_sma10, how='inner', on='index'), how='inner', on='index'),how='inner', on='index')).rename(columns={'index':'subtask'})
## let play whith the data ()

# %%
stats_exp_pro_sma10['estimated_total_time'] = stats_exp_pro_sma10['count_entries'] * stats_exp_pro_sma10['median_time__entries']
stats_exp_pro_sma10['estimated_%_f4_total_time'] = round(100 *stats_exp_pro_sma10.estimated_total_time / sma10_exp_pro.Time_Decimal.sum(), 2)
stats_exp_pro_sma10['estimated_total_cost'] = stats_exp_pro_sma10['count_entries'] * stats_exp_pro_sma10['avg_cost_subtask']
stats_exp_pro_sma10['estimated_%_f4_total_cost'] = round(100 *stats_exp_pro_sma10.estimated_total_cost / sma10_exp_pro.Task_Cost.sum(), 2)

stats_exp_pro_sma10['estimated_%_f4_total_cost'].reset_index()
# Out:
#     index  estimated_%_f4_total_cost
# 0       0                       0.16
# 1       1                       2.13
# 2       2                       3.32
# 3       3                       7.19
# 4       4                       0.29
# 5       5                       1.58
# 6       6                       7.74
# 7       7                       0.55
# 8       8                       8.31
# 9       9                       1.15
# 10     10                       2.48
# 11     11                       2.53
# 12     12                       1.99
# 13     13                       2.29
# 14     14                       1.58
# 15     15                       2.57
# 16     16                       2.94

# %% [markdown]
# # data for 10 largets projects'

# %%
lar10

# %%
def tasks_with_list_lar10(tup):
    pattern='|'.join(tup[1])
    return lar10_exp_pro[lar10_exp_pro.Task_Description.str.lower().str.contains(pattern, regex=True)]

# %%
def cal_cost_per_hour_lar10(words_list):
    return round( tasks_with_list_lar10(words_list).Task_Cost.sum() / tasks_with_list_lar10(words_list).Time_Decimal.sum() ,2)

# %%
# how many entries each of the subseted tasks has
count_entries_lar10 = (pd.Series({tup[0]:len(tasks_with_list_lar10(tup)) for tup in master_list_subjects})
                 .reset_index().rename(columns={0: 'count_entries'})) 

avg_cost_subset_task_lar10 = (pd.Series({ tup[0]:cal_cost_per_hour_lar10(tup) for tup in master_list_subjects })
                        .reset_index().rename(columns={0: 'avg_cost_subtask'}))

avg_time_entries_lar10 =( pd.Series({tup[0]:round(tasks_with_list_lar10(tup).Time_Decimal.mean(),2) for tup in master_list_subjects})
                   .reset_index().rename(columns={0: 'avg_time_entries'}))

median_time_entries_lar10 =(pd.Series({tup[0]:round(tasks_with_list_lar10(tup).Time_Decimal.median(),2) for tup in master_list_subjects})
                       .reset_index().rename(columns={0: 'median_time__entries'}))

# %%
## creating a data frame of all the subsettask information
stats_exp_pro_lar10=(pd.merge(count_entries_lar10, 
          pd.merge(avg_cost_subset_task_lar10, 
                   pd.merge(avg_time_entries_lar10,  
                            median_time_entries_lar10, how='inner', on='index'), how='inner', on='index'),how='inner', on='index')).rename(columns={'index':'subtask'})
## let play whith the data ()

# %%
stats_exp_pro_lar10['estimated_total_time'] = stats_exp_pro_lar10['count_entries'] * stats_exp_pro_lar10['median_time__entries']
stats_exp_pro_lar10['estimated_%_f4_total_time'] = round(100 *stats_exp_pro_lar10.estimated_total_time / lar10_exp_pro.Time_Decimal.sum(), 2)
stats_exp_pro_lar10['estimated_total_cost'] = stats_exp_pro_lar10['count_entries'] * stats_exp_pro_lar10['avg_cost_subtask']
stats_exp_pro_lar10['estimated_%_f4_total_cost'] = round(100 *stats_exp_pro_lar10.estimated_total_cost / lar10_exp_pro.Task_Cost.sum(), 2)

stats_exp_pro_lar10['avg_cost_subtask'].reset_index()
# Out:
#     index  avg_cost_subtask
# 0       0             19.84
# 1       1             39.00
# 2       2             34.20
# 3       3             30.26
# 4       4             29.65
# 5       5             33.19
# 6       6             30.13
# 7       7             27.62
# 8       8             31.50
# 9       9             31.72
# 10     10             33.06
# 11     11             32.51
# 12     12             37.43
# 13     13             33.15
# 14     14             32.61
# 15     15             27.59
# 16     16             27.00

# %%
stats_comper =(pd.merge(stats_exp_pro, 
          pd.merge(stats_exp_pro_lar10, 
                   stats_exp_pro_sma10, 
                   how='inner', on='subtask'), how='inner', on='subtask'))



stats_comper  = stats_comper[['subtask','count_entries', 'median_time__entries', 'estimated_%_f4_total_time', 'count_entries_x', 'median_time__entries_x', 'estimated_%_f4_total_time_x','count_entries_y', 'median_time__entries_y', 'estimated_%_f4_total_time_y']]
#['subtask','count_entries', 'median_time__entries', 'estimated_%_f4_total_time','count_entries_x', 'median_time__entries_x', 'estimated_%_f4_total_time_x','count_entries_y', 'median_time__entries_y', 'estimated_%_f4_total_time_y' ]

# %%
stats_comper
# Out:
#                  subtask  count_entries  median_time__entries  \
# 0             automation           1081                  1.18
# 1            code_review           1516                  1.50
# 2                 create           1175                  1.88
# 3             deployment           3656                  1.17
# 4          documentation            222                  2.18
# 5            environment            339                  1.47
# 6            fixing_bugs           3304                  2.00
# 7                helping            362                  1.58
# 8               meetings           3886                  0.67
# 9             onboarding            280                  1.64
# 10               planing           1499                  0.95
# 11  planning_n_designing           1558                  1.08
# 12              research            446                  2.09
# 13                server            474                  1.50
# ...
